# %% [markdown]
# ### Exercise 04.2
#
# By means of your upgraded code, <span style="color:red">perform MD simulations via a Lennard-Jones model</span> of Argon ($\sigma = 0.34$ nm, $\epsilon/k_B = 120$ K, $m=39.948$ amu) in the following conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
#
# and show in pictures the obtained progressive average values and uncertainties as a functions of the increasing number of blocks for the total (internal) energy per particle, $E/N$, the potential energy per particle, $U/N$, the kinetic energy per particle, $K/N$, the temperature, $T$, and the pressure, $P$, in reduced units!

# %% [markdown]
# ### <span style="color:green"> Equilibration is needed!</span>
#
# By monitoring the temperature, $T$, during the first time steps of the simulation, you will observe that at the beginning, starting from a perfect crystalline configuration, $T$ will not conserve its value. Can you understand and explain this behaviour?
#
# Explore and find the starting value of $T$ needed to stabilize, after a certain number of time steps (equilibration time), the average value of $T$ on the desired $T^\star$. <span style="color:red">Perform your solid/liquid phase MD simulations by re-starting them after such equilibration time.</span>

# %% [markdown]
# $FASE$ $LIQUIDA$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\temp_equilibration.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 1]
error_temp = temp[:, 3]
block = temp[:, 0]

# Crea l'erroreplot
plt.plot(block, temp_ave)
plt.axhline(y=1.1, color='r', label='T=1.1')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature equilibration (liquid phase)')
plt.legend()

# Mostra il grafico
plt.show()

# %% [markdown]
# Dopo circa 1000 step la temperatura inizia ad oscillare attorno alla $T$ desiderata (dove come $T$ di partenza ho usato 1.98).

# %% [markdown]
# $Calcolo$ $delle$ $variabili$ $termodinamiche$ $dopo$ $l'equilibrazione:$

# %%
# Leggi i dati dal file
pressure = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\pressure.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
pressure_ave = pressure[:, 2]
err_pressure = pressure[:, 3]
block = pressure[:, 0]

# Crea l'erroreplot
plt.errorbar(block, pressure_ave, yerr=err_pressure, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=pressure_ave[-1], color='r', linestyle='--', label=f'Last pressure_ave = {pressure_ave[-1]:.3f}')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Pressure')
plt.title('Pressure (in natural units)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\temp.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 2]
err_temp = temp[:, 3]
block = temp[:, 0]

# Crea l'erroreplot
plt.errorbar(block, temp_ave, yerr=err_temp, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=temp_ave[-1], color='r', linestyle='--', label=f'Last temp_ave = {temp_ave[-1]:.3f}')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature (in natural units for a liquid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
kin = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\kinetic.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
kin_ave = kin[:, 2]
err_kin = kin[:, 3]
block = kin[:, 0]

# Crea l'erroreplot
plt.errorbar(block, kin_ave, yerr=err_kin, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=kin_ave[-1], color='r', linestyle='--', label=f'Last kin_ave = {kin_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Kinetic energy')
plt.title('kinetic energy (in natural units for a liquid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
PE = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\PE.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
PE_ave = PE[:, 2]
err_PE = PE[:, 3]
block = PE[:, 0]

# Crea l'erroreplot
plt.errorbar(block, PE_ave, yerr=err_PE, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=PE_ave[-1], color='r', linestyle='--', label=f'Last PE_ave = {PE_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Potential energy')
plt.title('Potential energy (in natural units for a liquid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
Etot = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\liquid_phase\E_tot.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
Etot_ave = Etot[:, 2]
err_Etot = Etot[:, 3]
block = Etot[:, 0]

# Crea l'erroreplot
plt.errorbar(block, Etot_ave, yerr=err_Etot, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=Etot_ave[-1], color='r', linestyle='--', label=f'Last Etot_ave = {Etot_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Total energy')
plt.title('Total energy (in natural units for a liquid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %% [markdown]
# $FASE$ $SOLIDA$

# %%
# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\temp_equilibration.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 1]
error_temp = temp[:, 3]
block = temp[:, 0]

# Crea l'erroreplot
plt.plot(block, temp_ave)
plt.axhline(y=0.8, color='r', label='T=0.8')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature equilibration (solid phase)')
plt.legend()

# Mostra il grafico
plt.show()

# %% [markdown]
# Dopo circa 1000 step inizia ad oscillare attorno alla $T$ desiderata (temperatura di partenza $T=1,55$

# %%
# Leggi i dati dal file
pressure = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\pressure.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
pressure_ave = pressure[:, 2]
err_pressure = pressure[:, 3]
block = pressure[:, 0]

# Crea l'erroreplot
plt.errorbar(block, pressure_ave, yerr=err_pressure, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=pressure_ave[-1], color='r', linestyle='--', label=f'Last pressure_ave = {pressure_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Pressure')
plt.title('Pressure (in natural units for a solid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\temp.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 2]
err_temp = temp[:, 3]
block = temp[:, 0]

# Crea l'erroreplot
plt.errorbar(block, temp_ave, yerr=err_temp, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=temp_ave[-1], color='r', linestyle='--', label=f'Last temp_ave = {temp_ave[-1]:.3f}')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature (in natural units for a solid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
kin = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\kinetic.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
kin_ave = kin[:, 2]
err_kin = kin[:, 3]
block = kin[:, 0]

# Crea l'erroreplot
plt.errorbar(block, kin_ave, yerr=err_kin, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=kin_ave[-1], color='r', linestyle='--', label=f'Last kin_ave = {kin_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Kinetic energy')
plt.title('kinetic energy (in natural units for a solid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
PE = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\PE.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
PE_ave = PE[:, 2]
err_PE = PE[:, 3]
block = PE[:, 0]

# Crea l'erroreplot
plt.errorbar(block, PE_ave, yerr=err_PE, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=PE_ave[-1], color='r', linestyle='--', label=f'Last PE_ave = {PE_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Potential energy')
plt.title('Potential energy (in natural units for a solid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
Etot = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\solid_phase\E_tot.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
Etot_ave = Etot[:, 2]
err_Etot = Etot[:, 3]
block = Etot[:, 0]

# Crea l'erroreplot
plt.errorbar(block, Etot_ave, yerr=err_Etot, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=Etot_ave[-1], color='r', linestyle='--', label=f'Last Etot_ave = {Etot_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Total energy')
plt.title('Total energy (in natural units for a solid phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %% [markdown]
# $GAS$ $PHASE$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\temp_equilibration.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 1]
block = temp[:, 0]

# Crea l'erroreplot
plt.plot(block, temp_ave)
plt.axhline(y=1.2, color='r', label='T=1.2')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature equilibration (gas phase)')
plt.legend()

# Mostra il grafico
plt.show()

# %% [markdown]
# Il gas non è facile da equilibrare. In ogni caso dopo circa 6000 steps la $T$ inizia ad oscillare attorno a quella desiderata (con $T$ di partenza T=0.96)

# %%
# Leggi i dati dal file
pressure = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\pressure.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
pressure_ave = pressure[:, 2]
err_pressure = pressure[:, 3]
block = pressure[:, 0]

# Crea l'erroreplot
plt.errorbar(block, pressure_ave, yerr=err_pressure, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=pressure_ave[-1], color='r', linestyle='--', label=f'Last pressure_ave = {pressure_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Pressure')
plt.title('Pressure (in natural units for a gas phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
temp = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\temp.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
temp_ave = temp[:, 2]
err_temp = temp[:, 3]
block = temp[:, 0]

# Crea l'erroreplot
plt.errorbar(block, temp_ave, yerr=err_temp, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=temp_ave[-1], color='r', linestyle='--', label=f'Last temp_ave = {temp_ave[-1]:.3f}')

# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Temperature')
plt.title('Temperature (in natural units for a gas phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
kin = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\kinetic.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
kin_ave = kin[:, 2]
err_kin = kin[:, 3]
block = kin[:, 0]

# Crea l'erroreplot
plt.errorbar(block, kin_ave, yerr=err_kin, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=kin_ave[-1], color='r', linestyle='--', label=f'Last kin_ave = {kin_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Kinetic energy')
plt.title('kinetic energy (in natural units for a gas phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
PE = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\PE.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
PE_ave = PE[:, 2]
err_PE = PE[:, 3]
block = PE[:, 0]

# Crea l'erroreplot
plt.errorbar(block, PE_ave, yerr=err_PE, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=PE_ave[-1], color='r', linestyle='--', label=f'Last PE_ave = {PE_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Potential energy')
plt.title('Potential energy (in natural units for a gas phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()

# %%
# Leggi i dati dal file
Etot = np.loadtxt(r'C:\Users\Utente\Documents\Python Scripts\lezione_4\gas_phase\E_tot.txt', skiprows=1)  # Salta la riga dell'intestazione

# Estrai i valori delle colonne
Etot_ave = Etot[:, 2]
err_Etot = Etot[:, 3]
block = Etot[:, 0]

# Crea l'erroreplot
plt.errorbar(block, Etot_ave, yerr=err_Etot, fmt='o', capsize=3, color='blue', ecolor='c', markersize=6)

plt.axhline(y=Etot_ave[-1], color='r', linestyle='--', label=f'Last Etot_ave = {Etot_ave[-1]:.3f}')


# Aggiungi etichette agli assi e un titolo al grafico
plt.xlabel('BLOCKS')
plt.ylabel('Total energy')
plt.title('Total energy (in natural units for a gas phase in a Lennard-Jones potential)')
plt.legend()

# Mostra il grafico
plt.show()
